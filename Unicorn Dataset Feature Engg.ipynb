# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\PowerBI Reports Lalwani\Dataset Links\Unicorn_Companies.csv", encoding = "utf-8")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   object
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1037 non-null   object
#  7   Founded Year       1037 non-null   object
#  8   Total Raised       1037 non-null   object
#  9   Financial Stage    1037 non-null   object
#  10  Investors Count    1037 non-null   object
#  11  Deal Terms         1037 non-null   object
#  12  Portfolio Exits    1037 non-null   object
# dtypes: object(13)
# memory usage: 105.4+ KB

# %%
data.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
data.isnull().sum()
# Out:
# Company              0
# Valuation ($B)       0
# Date Joined          0
# Country              0
# City                 0
# Industry             0
# Select Inverstors    0
# Founded Year         0
# Total Raised         0
# Financial Stage      0
# Investors Count      0
# Deal Terms           0
# Portfolio Exits      0
# dtype: int64

# %%
data[data['Country']=='India']
# Out:
#                 Company Valuation ($B) Date Joined Country       City  \
# 13               BYJU's            $21   7/25/2017   India  Bengaluru
# 40               Swiggy          $10.7   6/21/2018   India  Bengaluru
# 58            OYO Rooms           $9.6   9/25/2018   India   Gurugram
# 68              Dream11             $8    4/9/2019   India     Mumbai
# 77             Razorpay           $7.5  10/11/2020   India  Bengaluru
# ...                 ...            ...         ...     ...        ...
# 993            NoBroker             $1  11/23/2021   India  Bengaluru
# 994               Slice             $1  11/28/2021   India  Bengaluru
# 1015  Fractal Analytics             $1    1/5/2022   India     Mumbai
# 1020          Darwinbox             $1   1/25/2022   India  Hyderabad
# 1031             Hasura             $1   2/22/2022   India  Bengaluru
#
#                                  Industry  \
# 13                                 Edtech
# ...

# %%
train_df=data.copy()

# %%
train_df['Valuation ($B)'].unique()
# Out:
# array(['$140', '$100.3', '$95', '$45.6', '$42', '$40', '$39', '$38',
#        '$33', '$32', '$27', '$25', '$21', '$20', '$17.5', '$15.5', '$15',
#        '$13.4', '$13.3', '$13', '$12.6', '$12.4', '$12.3', '$12', '$11.7',
#        '$11.4', '$11.1', '$11', '$10.2', '$10.88', '$10.7', '$10', '$9.5',
#        '$9.28', '$9.23', '$9.2', '$9.08', '$9', '$9.6', '$8.75', '$8.7',
#        '$8.6', '$8.4', '$8.3', '$8.1', '$8', '$7.83', '$7.6', '$7.75',
#        '$7.5', '$7.4', '$7.3', '$7.25', '$7.1', '$7', '$6.8', '$6.6',
#        '$6.5', '$6.3', '$6.28', '$6.2', '$6.1', '$6', '$5.2', '$5.99',
#        '$5.78', '$5.77', '$5.7', '$5.6', '$5.3', '$5.25', '$5.1', '$5.05',
#        '$5', '$5.5', '$4.9', '$4.8', '$4.73', '$4.7', '$4.6', '$5.85',
#        '$4.58', '$4.53', '$4.5', '$4.4', '$4.3', '$4.2', '$4.25', '$4.15',
#        '$4.1', '$4.11', '$4', '$4.01', '$3.92', '$3.8', '$3.75', '$3.7',
#        '$3.6', '$3.52', '$3.5', '$3.44', '$3.4', '$3.35', '$3.32',
# ...

# %%
train_df['Valuation in $B']=train_df['Valuation ($B)'].str.split('$').str[1]

# %%
train_df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
train_df['Joining Year']=train_df['Date Joined'].str.split("/").str[2]

# %%
train_df['Joining Month']=train_df['Date Joined'].str.split("/").str[1]

# %%
train_df['Joining Day']=train_df['Date Joined'].str.split("/").str[0]

# %%
train_df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
train_df['Founded Year'].unique()
# Out:
# array(['2012', '2002', '2010', '2005', '1991', '2013', '2015', '2018',
#        '1995', '2008', '2011', '2006', '2016', '2017', '2009', '2003',
#        '1998', '2014', 'None', '2001', '2007', '2019', '1996', '1992',
#        '2004', '2020', '1999', '1994', '2000', '1919', '2021', '1973',
#        '1979', '1984', '1990', '1997', '1993'], dtype=object)

# %%
train_df[train_df['Founded Year']=='None']
# Out:
#                   Company Valuation ($B) Date Joined         Country  \
# 39                Weilong         $10.88    5/8/2021           China
# 74                  Hopin          $7.75  11/10/2020  United Kingdom
# 81                Argo AI          $7.25   7/12/2019   United States
# 94               Ola Cabs           $7.5  10/27/2014           India
# 124               C6 Bank          $5.05   12/2/2020          Brazil
# 146               Chipone          $4.73  12/20/2021           China
# 170                SSENSE          $4.15    6/8/2021          Canada
# 175                  CRED          $4.01    4/6/2021           India
# 184                Zapier             $4   1/14/2021   United States
# 185             Clubhouse             $4   1/24/2021   United States
# 342                 Paxos           $2.4   4/29/2021   United States
# 391            Tubatu.com             $2    3/9/2015           China
# 449               Netlify             $2  11/17/2021   United States
# ...

# %%
train_df.shape
# Out:
# (1037, 17)

# %%
train_df['Founded Year'].mode()
# Out:
# 0    2015
# dtype: object

# %%
train_df[train_df['Founded Year']!='2013']['Founded Year']
# Out:
# 0       2012
# 1       2002
# 2       2010
# 3       2005
# 4       1991
#         ...
# 1032    2015
# 1033    2019
# 1034    2011
# 1035    2017
# 1036    2008
# Name: Founded Year, Length: 952, dtype: object

# %%
train_df['Founded Year'].replace('None',2015)
# Out:
# 0       2012
# 1       2002
# 2       2010
# 3       2005
# 4       1991
#         ...
# 1032    2015
# 1033    2019
# 1034    2011
# 1035    2017
# 1036    2008
# Name: Founded Year, Length: 1037, dtype: object

# %%
train_df['Founded Year']=train_df['Founded Year'].replace('None',2015)

# %%
train_df['Founded Year'].head()
# Out:
# 0    2012
# 1    2002
# 2    2010
# 3    2005
# 4    1991
# Name: Founded Year, dtype: object

# %%
train_df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
train_df['Total Raised']
# Out:
# 0         $7.44B
# 1        $6.874B
# 2        $2.901B
# 3        $3.472B
# 4        $4.377B
#           ...
# 1032    $181.06M
# 1033       $700M
# 1034    $449.72M
# 1035     $525.5M
# 1036     $604.5M
# Name: Total Raised, Length: 1037, dtype: object

# %%
train_df['Total Raised'] = train_df['Total Raised'].str.split("$").str[1]

# %%
train_df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
train_df['Total Raised'].str[0]
# Out:
# 0       7
# 1       6
# 2       2
# 3       3
# 4       4
#        ..
# 1032    1
# 1033    7
# 1034    4
# 1035    5
# 1036    6
# Name: Total Raised, Length: 1037, dtype: object

# %%
train_df.dropna(axis=0,how='any')
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           $140    4/7/2017          China        Beijing
# 1           SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2           Stripe            $95   1/23/2014  United States  San Francisco
# 3           Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4       Epic Games            $42  10/26/2018  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# ...

# %%
train_df['Total Raised'].isnull().sum()
# Out:
# 0

# %%
train_df['Total Raised']=train_df['Total Raised'].dropna()

# %%
train_df['Total Raised'].isnull().sum()
# Out:
# 0

# %%
train_df['Total Raised']
# Out:
# 0       nan
# 1       nan
# 2       nan
# 3       nan
# 4       nan
#        ...
# 1032    nan
# 1033    nan
# 1034    nan
# 1035    nan
# 1036    nan
# Name: Total Raised, Length: 1037, dtype: object

# %%
train_df
# Out:
#            Company Valuation ($B) Date Joined        Country           City  \
# 0        Bytedance           $140    4/7/2017          China        Beijing
# 1           SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2           Stripe            $95   1/23/2014  United States  San Francisco
# 3           Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4       Epic Games            $42  10/26/2018  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale             $1   2/22/2022  United States       New York
# 1033      Scalapay             $1   2/23/2022          Italy          Milan
# 1034  Omada Health             $1   2/23/2022  United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022  United States       New York
# 1036          Veev             $1   2/24/2022  United States      San Mateo
#
#                           Industry  \
# ...

# %%
train_df['Total Raised']=data['Total Raised']

# %%
train_df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
train_df[train_df['Financial Stage']=='None']
# Out:
#            Company Valuation ($B) Date Joined         Country           City  \
# 1           SpaceX         $100.3   12/1/2012   United States      Hawthorne
# 5            Canva            $40    1/8/2018       Australia    Surry Hills
# 6     Checkout.com            $40    5/2/2019  United Kingdom         London
# 7        Instacart            $39  12/30/2014   United States  San Francisco
# 8       Databricks            $38    2/5/2019   United States  San Francisco
# ...            ...            ...         ...             ...            ...
# 1032     Timescale             $1   2/22/2022   United States       New York
# 1033      Scalapay             $1   2/23/2022           Italy          Milan
# 1034  Omada Health             $1   2/23/2022   United States  San Francisco
# 1035    BlueVoyant             $1   2/23/2022   United States       New York
# 1036          Veev             $1   2/24/2022   United States      San Mateo
#
#                                  Industry  \
# ...

# %%
train_df.drop(columns='Financial Stage',inplace=True)

# %%
train_df.drop(columns=['Valuation ($B)','Date Joined'],inplace=True)

# %%
train_df.head()
# Out:
#       Company        Country           City                 Industry  \
# 0   Bytedance          China        Beijing  Artificial intelligence
# 1      SpaceX  United States      Hawthorne                    Other
# 2      Stripe  United States  San Francisco                  Fintech
# 3      Klarna         Sweden      Stockholm                  Fintech
# 4  Epic Games  United States           Cary                    Other
#
#                                    Select Inverstors Founded Year  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2012
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2        Khosla Ventures, LowercaseCapital, capitalG         2010
# 3  Institutional Venture Partners, Sequoia Capita...         2005
# 4              Tencent Holdings, KKR, Smash Ventures         1991
#
#   Total Raised Investors Count Deal Terms Portfolio Exits Valuation in $B  \
# 0       $7.44B              28          8               5             140
# ...

# %%
train_df['Investors Count'].unique()
# Out:
# array(['28', '29', '39', '56', '25', '26', '15', '31', '40', '21', '24',
#        '45', '9', '18', '7', '8', '16', '13', '34', '14', '10', '41',
#        '19', '6', '37', '27', '36', '20', '70', '33', '17', '22', '54',
#        '35', '11', '85', '32', '1', '2', '30', '12', '23', '4', '5', '38',
#        '3', '53', '44', '43', '46', '42', 'None', '91', '55'],
#       dtype=object)

# %%
train_df[train_df['Investors Count']=='None']
# Out:
#     Company        Country          City               Industry  \
# 680    Fair  United States  Santa Monica  Auto & transportation
#
#                                      Select Inverstors Founded Year  \
# 680  CreditEase Fintech Investment Fund, BMW i Vent...         2015
#
#     Total Raised Investors Count Deal Terms Portfolio Exits Valuation in $B  \
# 680         $20M            None          1            None             1.2
#
#     Joining Year Joining Month Joining Day
# 680         2018            20          12

# %%
train_df.drop(index=680,inplace=True)

# %%
train_df[train_df['Investors Count']=='None']
# Out:
# Empty DataFrame
# Columns: [Company, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Investors Count, Deal Terms, Portfolio Exits, Valuation in $B, Joining Year, Joining Month, Joining Day]
# Index: []

# %%
train_df['Investors Count'].unique()
# Out:
# array(['28', '29', '39', '56', '25', '26', '15', '31', '40', '21', '24',
#        '45', '9', '18', '7', '8', '16', '13', '34', '14', '10', '41',
#        '19', '6', '37', '27', '36', '20', '70', '33', '17', '22', '54',
#        '35', '11', '85', '32', '1', '2', '30', '12', '23', '4', '5', '38',
#        '3', '53', '44', '43', '46', '42', '91', '55'], dtype=object)

# %%
train_df.head()
# Out:
#       Company        Country           City                 Industry  \
# 0   Bytedance          China        Beijing  Artificial intelligence
# 1      SpaceX  United States      Hawthorne                    Other
# 2      Stripe  United States  San Francisco                  Fintech
# 3      Klarna         Sweden      Stockholm                  Fintech
# 4  Epic Games  United States           Cary                    Other
#
#                                    Select Inverstors Founded Year  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2012
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2        Khosla Ventures, LowercaseCapital, capitalG         2010
# 3  Institutional Venture Partners, Sequoia Capita...         2005
# 4              Tencent Holdings, KKR, Smash Ventures         1991
#
#   Total Raised Investors Count Deal Terms Portfolio Exits Valuation in $B  \
# 0       $7.44B              28          8               5             140
# ...

# %%
train_df['Deal Terms'].unique()
# Out:
# array(['8', '12', '13', '5', '4', '6', '3', '10', '9', '19', '1', '7',
#        '2', '11', 'None', '14'], dtype=object)

# %%
train_df[train_df['Deal Terms']=='None'].shape
# Out:
# (29, 14)

# %%
train_df[train_df['Deal Terms']=='1']
# Out:
#                      Company        Country           City  \
# 16                      Miro  United States  San Francisco
# 31    Biosplice Therapeutics  United States      San Diego
# 32                  GoodLeap  United States      Roseville
# 39                   Weilong          China          Luohe
# 81                   Argo AI  United States     Pittsburgh
# ...                      ...            ...            ...
# 1025          Dune Analytics         Norway           Oslo
# 1028               Watershed  United States  San Francisco
# 1029                  Axelar         Canada       Waterloo
# 1031                  Hasura          India      Bengaluru
# 1036                    Veev  United States      San Mateo
#
#                           Industry  \
# 16    Internet software & services
# 31                          Health
# 32    Internet software & services
# 39               Consumer & retail
# 81         Artificial intelligence
# ...                            ...
# ...

# %%
train_df['Deal Terms'].replace('None','1',inplace=True)

# %%
train_df[train_df['Deal Terms']=='None']
# Out:
# Empty DataFrame
# Columns: [Company, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Investors Count, Deal Terms, Portfolio Exits, Valuation in $B, Joining Year, Joining Month, Joining Day]
# Index: []

# %%
train_df['Deal Terms'].unique()
# Out:
# array(['8', '12', '13', '5', '4', '6', '3', '10', '9', '19', '1', '7',
#        '2', '11', '14'], dtype=object)

# %%
train_df.head()
# Out:
#       Company        Country           City                 Industry  \
# 0   Bytedance          China        Beijing  Artificial intelligence
# 1      SpaceX  United States      Hawthorne                    Other
# 2      Stripe  United States  San Francisco                  Fintech
# 3      Klarna         Sweden      Stockholm                  Fintech
# 4  Epic Games  United States           Cary                    Other
#
#                                    Select Inverstors Founded Year  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2012
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2        Khosla Ventures, LowercaseCapital, capitalG         2010
# 3  Institutional Venture Partners, Sequoia Capita...         2005
# 4              Tencent Holdings, KKR, Smash Ventures         1991
#
#   Total Raised Investors Count Deal Terms Portfolio Exits Valuation in $B  \
# 0       $7.44B              28          8               5             140
# ...

# %%
train_df[train_df['Portfolio Exits']=='None']
# Out:
#            Company         Country           City  \
# 1           SpaceX   United States      Hawthorne
# 5            Canva       Australia    Surry Hills
# 6     Checkout.com  United Kingdom         London
# 7        Instacart   United States  San Francisco
# 8       Databricks   United States  San Francisco
# ...            ...             ...            ...
# 1032     Timescale   United States       New York
# 1033      Scalapay           Italy          Milan
# 1034  Omada Health   United States  San Francisco
# 1035    BlueVoyant   United States       New York
# 1036          Veev   United States      San Mateo
#
#                                  Industry  \
# 1                                   Other
# 5            Internet software & services
# 6                                 Fintech
# 7     Supply chain, logistics, & delivery
# 8             Data management & analytics
# ...                                   ...
# 1032         Internet software & services
# ...

# %%
train_df.drop(columns='Portfolio Exits',inplace=True)

# %%
train_df.head()
# Out:
#       Company        Country           City                 Industry  \
# 0   Bytedance          China        Beijing  Artificial intelligence
# 1      SpaceX  United States      Hawthorne                    Other
# 2      Stripe  United States  San Francisco                  Fintech
# 3      Klarna         Sweden      Stockholm                  Fintech
# 4  Epic Games  United States           Cary                    Other
#
#                                    Select Inverstors Founded Year  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2012
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2        Khosla Ventures, LowercaseCapital, capitalG         2010
# 3  Institutional Venture Partners, Sequoia Capita...         2005
# 4              Tencent Holdings, KKR, Smash Ventures         1991
#
#   Total Raised Investors Count Deal Terms Valuation in $B Joining Year  \
# 0       $7.44B              28          8             140         2017
# ...

# %%
train_df.drop(index = train_df[train_df['Select Inverstors']=='None'].index,inplace=True)

# %%
train_df[train_df['Select Inverstors']=='None']
# Out:
# Empty DataFrame
# Columns: [Company, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Investors Count, Deal Terms, Valuation in $B, Joining Year, Joining Month, Joining Day]
# Index: []

# %%
train_df.shape
# Out:
# (1019, 13)

# %%
train_df['Total Raised'].replace('None',0,inplace=True)

# %%
train_df['Valuation in $B']
# Out:
# 0         140
# 1       100.3
# 2          95
# 3        45.6
# 4          42
#         ...
# 1032        1
# 1033        1
# 1034        1
# 1035        1
# 1036        1
# Name: Valuation in $B, Length: 1019, dtype: object

# %%
train_df['Total Raised in $']=train_df['Total Raised'].str.split('$').str[1]

# %%
train_df.head()
# Out:
#       Company        Country           City                 Industry  \
# 0   Bytedance          China        Beijing  Artificial intelligence
# 1      SpaceX  United States      Hawthorne                    Other
# 2      Stripe  United States  San Francisco                  Fintech
# 3      Klarna         Sweden      Stockholm                  Fintech
# 4  Epic Games  United States           Cary                    Other
#
#                                    Select Inverstors Founded Year  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2012
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2        Khosla Ventures, LowercaseCapital, capitalG         2010
# 3  Institutional Venture Partners, Sequoia Capita...         2005
# 4              Tencent Holdings, KKR, Smash Ventures         1991
#
#   Total Raised Investors Count Deal Terms Valuation in $B Joining Year  \
# 0       $7.44B              28          8             140         2017
# ...

# %%
train_df['Total Raised in $']
# Out:
# 0         7.44B
# 1        6.874B
# 2        2.901B
# 3        3.472B
# 4        4.377B
#          ...
# 1032    181.06M
# 1033       700M
# 1034    449.72M
# 1035     525.5M
# 1036     604.5M
# Name: Total Raised in $, Length: 1019, dtype: object

# %%
train_df.isnull().sum()
# Out:
# Company               0
# Country               0
# City                  0
# Industry              0
# Select Inverstors     0
# Founded Year          0
# Total Raised          0
# Investors Count       0
# Deal Terms            0
# Valuation in $B       0
# Joining Year          0
# Joining Month         0
# Joining Day           0
# Total Raised in $    24
# dtype: int64

# %%
train_df['Total Raised in $']
# Out:
# 0         7.44B
# 1        6.874B
# 2        2.901B
# 3        3.472B
# 4        4.377B
#          ...
# 1032    181.06M
# 1033       700M
# 1034    449.72M
# 1035     525.5M
# 1036     604.5M
# Name: Total Raised in $, Length: 1019, dtype: object

# %%
train_df[train_df['Total Raised in $'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Investors Count, Deal Terms, Valuation in $B, Joining Year, Joining Month, Joining Day, Total Raised in $]
# Index: []

# %%
train_df['Total Raised in $'].fillna(0,inplace=True)

# %%
train_df[train_df['Total Raised in $'].isnull()].shape
# Out:
# (0, 14)

# %%
train_df.isnull().sum()
# Out:
# Company              0
# Country              0
# City                 0
# Industry             0
# Select Inverstors    0
# Founded Year         0
# Total Raised         0
# Investors Count      0
# Deal Terms           0
# Valuation in $B      0
# Joining Year         0
# Joining Month        0
# Joining Day          0
# Total Raised in $    0
# dtype: int64

# %%
train_df.head()
# Out:
#       Company        Country           City                 Industry  \
# 0   Bytedance          China        Beijing  Artificial intelligence
# 1      SpaceX  United States      Hawthorne                    Other
# 2      Stripe  United States  San Francisco                  Fintech
# 3      Klarna         Sweden      Stockholm                  Fintech
# 4  Epic Games  United States           Cary                    Other
#
#                                    Select Inverstors Founded Year  \
# 0  Sequoia Capital China, SIG Asia Investments, S...         2012
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2        Khosla Ventures, LowercaseCapital, capitalG         2010
# 3  Institutional Venture Partners, Sequoia Capita...         2005
# 4              Tencent Holdings, KKR, Smash Ventures         1991
#
#   Total Raised Investors Count Deal Terms Valuation in $B Joining Year  \
# 0       $7.44B              28          8             140         2017
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1019 non-null   object
#  1   Country            1019 non-null   object
#  2   City               1019 non-null   object
#  3   Industry           1019 non-null   object
#  4   Select Inverstors  1019 non-null   object
#  5   Founded Year       1019 non-null   int32
#  6   Investors Count    1019 non-null   int32
#  7   Deal Terms         1019 non-null   int32
#  8   Valuation in $B    1019 non-null   float64
#  9   Joining Year       1019 non-null   object
#  10  Joining Month      1019 non-null   object
#  11  Joining Day        1019 non-null   object
#  12  Total Raised in $  1019 non-null   object
# dtypes: float64(1), int32(3), object(9)
# memory usage: 99.5+ KB

# %%
train_df['Founded Year']=train_df['Founded Year'].astype(int)

# %%
train_df.drop(columns='Total Raised',inplace=True)

# %%
train_df['Investors Count']=train_df['Investors Count'].astypepe(int)

# %%
train_df['Deal Terms']=train_df['Deal Terms'].astypepe(int)

# %%
train_df['Valuation in $B']=train_df['Valuation in $B'].astype(float)

# %%
train_df['Joining Day']=train_df['Joining Day'].astype(int)

# %%
train_df['Joining Month']=train_df['Joining Month'].astype(int)

# %%
train_df['Joining Year']=train_df['Joining Year'].astype(int)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1019 non-null   object
#  1   Country            1019 non-null   object
#  2   City               1019 non-null   object
#  3   Industry           1019 non-null   object
#  4   Select Inverstors  1019 non-null   object
#  5   Founded Year       1019 non-null   int32
#  6   Investors Count    1019 non-null   int32
#  7   Deal Terms         1019 non-null   int32
#  8   Valuation in $B    1019 non-null   float64
#  9   Joining Year       1019 non-null   int32
#  10  Joining Month      1019 non-null   int32
#  11  Joining Day        1019 non-null   int32
#  12  Total Raised in $  1019 non-null   object
# dtypes: float64(1), int32(6), object(6)
# memory usage: 87.6+ KB

# %%
train_df['Total Raised in $'].str.contains('M').count()
# Out:
# 995

# %%
train_df.shape
# Out:
# (1019, 13)

# %%
train_df['Total Raised in $'].replace(0,'0M',inplace=True)

# %%
train_df[train_df['Total Raised in $']=='0M']
# Out:
#                   Company         Country           City  \
# 80               Scale AI   United States  San Francisco
# 94               Ola Cabs           India      Bengaluru
# 144              Cerebral   United States  San Francisco
# 157                 Monzo  United Kingdom         London
# 235             Starburst   United States         Boston
# 342                 Paxos   United States       New York
# 364           NuCom Group         Germany  Unterfoehring
# 384              ReCharge   United States    Los Angeles
# 410                   ISN   United States         Dallas
# 456            Cloudinary   United States    Santa Clara
# 481               Harness   United States  San Francisco
# 645             DistroKid   United States       New York
# 676           GalaxySpace           China        Beijing
# 689             Pilot.com   United States  San Francisco
# 805          Kendra Scott   United States         Austin
# ...

# %%
train_df.to_csv('Unicorn_Companies.csv',index=False)

# %%
with open('Unicorn_Companies.csv',mode='r') as f:
    f.close()

# %%
final_data = pd.read_csv('Unicorn_Companies.csv')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1019 non-null   object
#  1   Country            1019 non-null   object
#  2   City               1019 non-null   object
#  3   Industry           1019 non-null   object
#  4   Select Inverstors  1019 non-null   object
#  5   Founded Year       1019 non-null   int64
#  6   Investors Count    1019 non-null   int64
#  7   Deal Terms         1019 non-null   int64
#  8   Valuation in $B    1019 non-null   float64
#  9   Joining Year       1019 non-null   int64
#  10  Joining Month      1019 non-null   int64
#  11  Joining Day        1019 non-null   int64
#  12  Total Raised in $  1019 non-null   object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 103.6+ KB

# %%
# !pip install pymysql
# Out:
# ...
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# ...

# %%
final_data=pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\Unicorn_Companies.csv')

# %%
final_data
# Out:
#            Company        Country           City  \
# 0        Bytedance          China        Beijing
# 1           SpaceX  United States      Hawthorne
# 2           Stripe  United States  San Francisco
# 3           Klarna         Sweden      Stockholm
# 4       Epic Games  United States           Cary
# ...            ...            ...            ...
# 1014     Timescale  United States       New York
# 1015      Scalapay          Italy          Milan
# 1016  Omada Health  United States  San Francisco
# 1017    BlueVoyant  United States       New York
# 1018          Veev  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2                          Fintech
# 3                          Fintech
# 4                            Other
# ...                            ...
# 1014  Internet software & services
# 1015                       Fintech
# 1016                        Health
# ...

# %%
final_data['Country'].unique()
# Out:
# array(['China', 'United States', 'Sweden', 'Australia', 'United Kingdom',
#        'India', 'Indonesia', 'Germany', 'Hong Kong', 'Mexico', 'Estonia',
#        'Canada', 'Turkey', 'South Korea', 'Netherlands', 'Israel',
#        'France', 'Finland', 'Colombia', 'Belgium', 'Brazil', 'Denmark',
#        'Lithuania', 'Austria', 'Ireland', 'Vietnam',
#        'United Arab Emirates', 'Switzerland', 'Argentina', 'Spain',
#        'Japan', 'Luxembourg', 'Nigeria', 'Philippines', 'Senegal',
#        'Malaysia', 'Bermuda', 'Norway', 'South Africa', 'Chile',
#        'Thailand', 'Czech Republic', 'Croatia', 'Italy'], dtype=object)

# %%
final_data[final_data['Country']=='Italy']['Founded Year']
# Out:
# 1015    2019
# Name: Founded Year, dtype: int64

# %%
final_data[final_data['Country']=='India']['Total Raised in $'].head()
# Out:
# 12     5.183B
# 39     3.571B
# 57     3.114B
# 67     1.165B
# 76    741.62M
# Name: Total Raised in $, dtype: object

# %%
India_df = pd.DataFrame(final_data[final_data['Country']=='India'],columns=['Company','City','Industry','Valuation in $B','Joining Year'])

# %%
India_df
# Out:
#                 Company       City                             Industry  \
# 12               BYJU's  Bengaluru                               Edtech
# 39               Swiggy  Bengaluru  Supply chain, logistics, & delivery
# 57            OYO Rooms   Gurugram                               Travel
# 67              Dream11     Mumbai         Internet software & services
# 76             Razorpay  Bengaluru                              Fintech
# ...                 ...        ...                                  ...
# 976            NoBroker  Bengaluru         Internet software & services
# 977               Slice  Bengaluru                              Fintech
# 997   Fractal Analytics     Mumbai          Data management & analytics
# 1002          Darwinbox  Hyderabad         Internet software & services
# 1013             Hasura  Bengaluru         Internet software & services
#
#       Valuation in $B  Joining Year
# 12               21.0          2017
# ...

# %%
pd.melt(India_df).tail(20)
# Out:
#          variable value
# 295  Joining Year  2021
# 296  Joining Year  2021
# 297  Joining Year  2021
# 298  Joining Year  2021
# 299  Joining Year  2022
# 300  Joining Year  2019
# 301  Joining Year  2021
# 302  Joining Year  2014
# 303  Joining Year  2014
# 304  Joining Year  2021
# 305  Joining Year  2021
# 306  Joining Year  2021
# 307  Joining Year  2021
# 308  Joining Year  2021
# 309  Joining Year  2021
# 310  Joining Year  2021
# 311  Joining Year  2021
# 312  Joining Year  2022
# 313  Joining Year  2022
# 314  Joining Year  2022

# %%
final_data['Industry'].unique()
# Out:
# array(['Artificial intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics', 'E-commerce & direct-to-consumer',
#        'Edtech', 'Hardware', 'Consumer & retail', 'Health',
#        'Auto & transportation', 'Finttech', 'Cybersecurity',
#        'Mobile & telecommunications', 'Travel', 'Artificial Intelligence'],
#       dtype=object)

# %%
final_data[final_data['Company']=='Bytedance']['Select Inverstors']
# Out:
# 0    Sequoia Capital China, SIG Asia Investments, S...
# Name: Select Inverstors, dtype: object

# %%
final_data[final_data['Country']=='India']['Select Inverstors'].unique()
# Out:
# array(['Tencent Holdings, Lightspeed India Partners, Sequoia Capital India',
#        'Accel India, SAIF Partners, Norwest Venture Partners',
#        'SoftBank Group, Sequoia Capital India,Lightspeed India Partners',
#        'Kaalari Capital, Tencent Holdings, Steadview Capital',
#        'Sequoia Capital India, Tiger Global Management, Matrix Partners India',
#        'TA Associates, SoftBank Group, GS Growth',
#        'Accel Partners, SoftBank Group, Sequoia Capital',
#        'Sequoia Capital India, Temasek, PayPal Ventures',
#        'Matrix Partners India, Falcon Edge Capital, SoftBank Group',
#        'SoftBank Group, Tiger Global Management, Matrix Partners India',
#        'Venture Highway, Sequoia Capital India, Prosus Ventures',
#        'Tiger Global Management, DST Global, Sequoia Capital India',
#        'India Quotient, Elevation Capital, Lightspeed Venture Partners',
#        'Fairfax Financial Holdings, A91 Partners, TVS Capital',
# ...

# %%
final_data.sort_values('Joining Year',ascending=False)
# Out:
#                          Company         Country                   City  \
# 1018                        Veev   United States              San Mateo
# 384                   GoCardless  United Kingdom                 London
# 287                    Inxeption   United States          San Francisco
# 591                     Firebolt          Israel               Tel Aviv
# 590               SparkCognition   United States                 Austin
# ...                          ...             ...                    ...
# 385   Trendy Group International       Hong Kong                Kowloon
# 10                      Fanatics   United States           Jacksonville
# 109                   Vice Media   United States               Brooklyn
# 3                         Klarna          Sweden              Stockholm
# 615                       Veepee          France  La Plaine Saint-Denis
#
#                              Industry  \
# 1018     Internet software & services
# ...
