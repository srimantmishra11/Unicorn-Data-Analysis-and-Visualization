# %%
import pymysql

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
final_df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\Unicorn_Companies.csv")

# %%
final_df
# Out:
#            Company        Country           City  \
# 0        Bytedance          China        Beijing
# 1           SpaceX  United States      Hawthorne
# 2           Stripe  United States  San Francisco
# 3           Klarna         Sweden      Stockholm
# 4       Epic Games  United States           Cary
# ...            ...            ...            ...
# 1014     Timescale  United States       New York
# 1015      Scalapay          Italy          Milan
# 1016  Omada Health  United States  San Francisco
# 1017    BlueVoyant  United States       New York
# 1018          Veev  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2                          Fintech
# 3                          Fintech
# 4                            Other
# ...                            ...
# 1014  Internet software & services
# 1015                       Fintech
# 1016                        Health
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1019 non-null   object
#  1   Country            1019 non-null   object
#  2   City               1019 non-null   object
#  3   Industry           1019 non-null   object
#  4   Select Inverstors  1019 non-null   object
#  5   Founded Year       1019 non-null   int64
#  6   Investors Count    1019 non-null   int64
#  7   Deal Terms         1019 non-null   int64
#  8   Valuation in $B    1019 non-null   float64
#  9   Joining Year       1019 non-null   int64
#  10  Joining Month      1019 non-null   int64
#  11  Joining Day        1019 non-null   int64
#  12  Total Raised in $  1019 non-null   object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 103.6+ KB

# %%
import mysql.connector as connection

# %%
conn = connection.connect(host="localhost",user="root",passwd="Bangalore11",use_pure=True)

# %%
conn

# %%
cur=conn.cursor()

# %%
cur.execute("show databases")

# %%
res = cur.fetchall()

# %%
res
# Out:
# [('hr_sample',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sql_datascience',),
#  ('srimant12345',),
#  ('student',),
#  ('sys',),
#  ('testsudhineuron',),
#  ('world',)]

# %%
import mysql.connector as connection
try:
    mydb=connection.connect(host='localhost',user="root",passwd="Bangalore11",use_pure=True)
    query="SHOW DATABASES"
    cursor=mydb.cursor()
    cursor.execute(query)
    print(cursor.fetchall())
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# [('hr_sample',), ('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sql_datascience',), ('srimant12345',), ('student',), ('sys',), ('testsudhineuron',), ('world',)]

# %%
# !pip install sqlalchemy

# %%
import sqlalchemy

# %%
engine=sqlalchemy.create_engine('mysql+pymysql://root:Bangalore11@localhost:3306/sql_datascience')

# %%
conn = "mysql+pymysql://{0}:{1}@{2}{3}".format(secrets.root)

# %%
df = pd.read_sql_table("ds_studs",engine)

# %%
df
# Out:
#    stu_id student_name  age gender        doa       city
# 0     101     Srimanta   23      M 2021-11-28  Bangalore
# 1     102   Aishwariya   22      F 2021-11-30  Hyderabad
# 2     103      Swadesh   23      M 2021-11-28    Colombo
# 3     104      Sampath   34      M 2022-01-21    Beijing

# %%
pd.read_sql_table("ds_studs",engine,columns=['student_name','age','gender'])
# Out:
#   student_name  age gender
# 0     Srimanta   23      M
# 1   Aishwariya   22      F
# 2      Swadesh   23      M
# 3      Sampath   34      M

# %%
final_df
# Out:
#            Company        Country           City  \
# 0        Bytedance          China        Beijing
# 1           SpaceX  United States      Hawthorne
# 2           Stripe  United States  San Francisco
# 3           Klarna         Sweden      Stockholm
# 4       Epic Games  United States           Cary
# ...            ...            ...            ...
# 1014     Timescale  United States       New York
# 1015      Scalapay          Italy          Milan
# 1016  Omada Health  United States  San Francisco
# 1017    BlueVoyant  United States       New York
# 1018          Veev  United States      San Mateo
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2                          Fintech
# 3                          Fintech
# 4                            Other
# ...                            ...
# 1014  Internet software & services
# 1015                       Fintech
# 1016                        Health
# ...

# %%
engine=sqlalchemy.create_engine('mysql+pymysql://root:Bangalore11@localhost:3306/unicorns')

# %%
final_df.to_sql(name='Unicorn Details',
               con=engine,
               index=False)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Unicorn Details' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
